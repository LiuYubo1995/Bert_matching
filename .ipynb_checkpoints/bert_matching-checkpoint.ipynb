# %%
import torch
import torch.nn as nn
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForSequenceClassification, BertAdam
import numpy as np
from tqdm import tqdm

# %%
import pandas as pd
file = pd.read_csv('quora.tsv', '\t')

# %%
def convert_lines(sentence, max_seq_length, tokenizer):
    max_seq_length -=2
    all_tokens = []
    for text in tqdm(sentence):
        tokens = tokenizer.tokenize(text)
        if len(tokens)>max_seq_length:
            tokens = tokens[:max_seq_length]
        padding_token = tokenizer.convert_tokens_to_ids(["[CLS]"]+tokens+["[SEP]"])+[0] * (max_seq_length - len(tokens))
        all_tokens.append(padding_token)
    return np.array(all_tokens)

# %%
max_sequence_length = 200
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', cache_dir=None, do_lower_case=True)
#file['question1'] = file['question1'].astype(str) 
question1 = convert_lines(file["question1"], max_sequence_length, tokenizer)
#file['question2'] = file['question2'].astype(str)
question2 = convert_lines(file["question2"], max_sequence_length, tokenizer)
label = np.array(file['is_duplicate'])
# Out:
# INFO:pytorch_pretrained_bert.tokenization:loading vocabulary file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /Users/LYB/.pytorch_pretrained_bert/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
#
#
#
#   0%|          | 0/404351 [00:00<?, ?it/s]
#
#
#   0%|          | 528/404351 [00:00<01:17, 5215.85it/s]
#
#
#   0%|          | 1135/404351 [00:00<01:14, 5445.14it/s]
#
#
#   0%|          | 1701/404351 [00:00<01:13, 5503.93it/s]
#
#
#   1%|          | 2270/404351 [00:00<01:12, 5553.43it/s]
#
#
#   1%|          | 2860/404351 [00:00<01:11, 5651.30it/s]
#
#
#   1%|          | 3482/404351 [00:00<01:09, 5809.40it/s]
#
#
#   1%|          | 4065/404351 [00:00<01:08, 5814.95it/s]
#
#
#   1%|          | 4649/404351 [00:00<01:08, 5819.38it/s]
#
#
#   1%|▏         | 5260/404351 [00:00<01:07, 5899.24it/s]
#
#
#   1%|▏         | 5830/404351 [00:01<01:11, 5537.23it/s]
#
#
#   2%|▏         | 6375/404351 [00:01<01:12, 5466.72it/s]
#
#
#   2%|▏         | 6977/404351 [00:01<01:10, 5620.65it/s]
#
#
#   2%|▏         | 7553/404351 [00:01<01:10, 5660.04it/s]
#
#
#   2%|▏         | 8117/404351 [00:01<01:10, 5584.25it/s]
#
#
#   2%|▏         | 8722/404351 [00:01<01:09, 5714.94it/s]
#
#
#   2%|▏         | 9317/404351 [00:01<01:08, 5782.55it/s]
#
#
#   2%|▏         | 9919/404351 [00:01<01:07, 5850.79it/s]
#
#
#   3%|▎         | 10536/404351 [00:01<01:06, 5941.86it/s]
#
#
#   3%|▎         | 11131/404351 [00:01<01:06, 5906.14it/s]
#
#
#   3%|▎         | 11727/404351 [00:02<01:06, 5921.14it/s]
#
#
#   3%|▎         | 12320/404351 [00:02<01:06, 5878.80it/s]
#
#
#   3%|▎         | 12934/404351 [00:02<01:05, 5953.10it/s]
#
#
#   3%|▎         | 13567/404351 [00:02<01:04, 6059.78it/s]
#
#
#   4%|▎         | 14188/404351 [00:02<01:03, 6102.87it/s]
#
#
#   4%|▎         | 14799/404351 [00:02<01:04, 6042.12it/s]
#
#
#   4%|▍         | 15404/404351 [00:02<01:04, 6014.05it/s]
#
#
#   4%|▍         | 16038/404351 [00:02<01:03, 6105.45it/s]
#
#
#   4%|▍         | 16650/404351 [00:02<01:06, 5825.85it/s]
#
#
#   4%|▍         | 17251/404351 [00:02<01:05, 5875.95it/s]
#
#
#   4%|▍         | 17863/404351 [00:03<01:05, 5945.23it/s]
#
#
#   5%|▍         | 18483/404351 [00:03<01:04, 6018.26it/s]
#
#
#   5%|▍         | 19116/404351 [00:03<01:03, 6108.30it/s]
#
#
#   5%|▍         | 19729/404351 [00:03<01:03, 6096.16it/s]
#
#
#   5%|▌         | 20340/404351 [00:03<01:03, 6060.77it/s]
#
#
#   5%|▌         | 20947/404351 [00:03<01:03, 6000.23it/s]
#
#
#   5%|▌         | 21572/404351 [00:03<01:03, 6070.60it/s]
#
#
#   5%|▌         | 22206/404351 [00:03<01:02, 6147.86it/s]
#
#
#   6%|▌         | 22831/404351 [00:03<01:01, 6176.19it/s]
#
#
#   6%|▌         | 23450/404351 [00:03<01:02, 6083.62it/s]
#
#
#   6%|▌         | 24060/404351 [00:04<01:02, 6067.60it/s]
#
#
#   6%|▌         | 24676/404351 [00:04<01:02, 6092.03it/s]
#
#
#   6%|▋         | 25286/404351 [00:04<01:04, 5865.06it/s]
#
#
#   6%|▋         | 25894/404351 [00:04<01:03, 5927.13it/s]
#
#
#   7%|▋         | 26489/404351 [00:04<01:04, 5875.03it/s]
#
#
#   7%|▋         | 27103/404351 [00:04<01:03, 5950.78it/s]
#
#
#   7%|▋         | 27731/404351 [00:04<01:02, 6042.94it/s]
#
#
#   7%|▋         | 28356/404351 [00:04<01:01, 6102.87it/s]
#
#
#   7%|▋         | 28968/404351 [00:04<01:01, 6080.71it/s]
#
#
#   7%|▋         | 29585/404351 [00:04<01:01, 6106.65it/s]
#
#
#   7%|▋         | 30197/404351 [00:05<01:01, 6052.59it/s]
#
#
#   8%|▊         | 30803/404351 [00:05<01:01, 6049.81it/s]
#
#
#   8%|▊         | 31442/404351 [00:05<01:00, 6147.01it/s]
#
#
#   8%|▊         | 32058/404351 [00:05<01:02, 5939.17it/s]
#
#
#   8%|▊         | 32675/404351 [00:05<01:01, 6005.81it/s]
#
#
#   8%|▊         | 33278/404351 [00:05<01:03, 5864.09it/s]
#
#
#   8%|▊         | 33878/404351 [00:05<01:02, 5903.85it/s]
#
#
#   9%|▊         | 34505/404351 [00:05<01:01, 6004.28it/s]
#
#
#   9%|▊         | 35142/404351 [00:05<01:00, 6106.41it/s]
#
#
#   9%|▉         | 35775/404351 [00:06<00:59, 6171.63it/s]
#
#
#   9%|▉         | 36404/404351 [00:06<00:59, 6206.18it/s]
#
#
#   9%|▉         | 37026/404351 [00:06<00:59, 6174.44it/s]
#
#
#   9%|▉         | 37645/404351 [00:06<01:00, 6090.10it/s]
#
#
#   9%|▉         | 38255/404351 [00:06<01:00, 6015.05it/s]
#
#
#  10%|▉         | 38866/404351 [00:06<01:00, 6042.56it/s]
#
#
#  10%|▉         | 39473/404351 [00:06<01:00, 6050.70it/s]
#
#
#  10%|▉         | 40104/404351 [00:06<00:59, 6125.61it/s]
#
#
#  10%|█         | 40718/404351 [00:06<01:00, 6048.30it/s]
#
#
#  10%|█         | 41324/404351 [00:06<01:01, 5926.26it/s]
#
#
#  10%|█         | 41918/404351 [00:07<01:03, 5679.55it/s]
#
#
#  11%|█         | 42489/404351 [00:07<01:03, 5680.37it/s]
#
#
#  11%|█         | 43060/404351 [00:07<01:03, 5684.24it/s]
#
#
#  11%|█         | 43680/404351 [00:07<01:01, 5828.48it/s]
#
#
#  11%|█         | 44300/404351 [00:07<01:00, 5932.84it/s]
#
#
#  11%|█         | 44896/404351 [00:07<01:01, 5849.67it/s]
#
#
#  11%|█         | 45483/404351 [00:07<01:01, 5834.78it/s]
#
#
#  11%|█▏        | 46115/404351 [00:07<00:59, 5972.02it/s]
#
#
#  12%|█▏        | 46714/404351 [00:07<00:59, 5974.07it/s]
#
#
#  12%|█▏        | 47313/404351 [00:07<00:59, 5963.63it/s]
#
#
#  12%|█▏        | 47923/404351 [00:08<00:59, 6002.73it/s]
#
#
#  12%|█▏        | 48524/404351 [00:08<00:59, 5946.90it/s]
#
#
#  12%|█▏        | 49133/404351 [00:08<00:59, 5986.64it/s]
#
#
#  12%|█▏        | 49733/404351 [00:08<01:00, 5849.60it/s]
#
#
#  12%|█▏        | 50319/404351 [00:08<01:01, 5779.95it/s]
#
#
#  13%|█▎        | 50939/404351 [00:08<00:59, 5897.60it/s]
#
#
#  13%|█▎        | 51530/404351 [00:08<01:00, 5828.47it/s]
#
#
#  13%|█▎        | 52114/404351 [00:08<01:00, 5782.71it/s]
#
#
#  13%|█▎        | 52741/404351 [00:08<00:59, 5919.11it/s]
#
#
#  13%|█▎        | 53355/404351 [00:08<00:58, 5981.83it/s]
#
#
#  13%|█▎        | 53996/404351 [00:09<00:57, 6101.93it/s]
#
#
#  14%|█▎        | 54612/404351 [00:09<00:57, 6117.88it/s]
#
#
#  14%|█▎        | 55236/404351 [00:09<00:56, 6151.75it/s]
#
#
#  14%|█▍        | 55861/404351 [00:09<00:56, 6180.83it/s]
#
#
#  14%|█▍        | 56480/404351 [00:09<00:57, 6096.36it/s]
#
#
#  14%|█▍        | 57091/404351 [00:09<00:57, 6057.60it/s]
#
#
#  14%|█▍        | 57698/404351 [00:09<00:57, 6009.51it/s]
#
#
#  14%|█▍        | 58300/404351 [00:09<00:58, 5874.82it/s]
#
#
#  15%|█▍        | 58918/404351 [00:09<00:57, 5962.69it/s]
#
#
#  15%|█▍        | 59516/404351 [00:10<00:58, 5921.55it/s]
#
#
#  15%|█▍        | 60109/404351 [00:10<00:58, 5842.16it/s]
#
#
#  15%|█▌        | 60765/404351 [00:10<00:56, 6040.32it/s]
#
#
#  15%|█▌        | 61375/404351 [00:10<00:56, 6055.67it/s]
#
#
#  15%|█▌        | 62009/404351 [00:10<00:55, 6137.31it/s]
#
#
#  15%|█▌        | 62625/404351 [00:10<00:55, 6109.00it/s]
#
#
#  16%|█▌        | 63237/404351 [00:10<00:56, 6037.69it/s]
#
#
#  16%|█▌        | 63848/404351 [00:10<00:56, 6056.41it/s]
#
#
#  16%|█▌        | 64455/404351 [00:10<00:56, 5994.28it/s]
#
#  34%|███▍      | 136893/404351 [00:23<00:44, 5952.10it/s]
#
#
#  34%|███▍      | 137513/404351 [00:23<00:44, 6022.56it/s]
#
#
#  34%|███▍      | 138148/404351 [00:23<00:43, 6114.06it/s]
#
#
#  34%|███▍      | 138761/404351 [00:23<00:43, 6050.74it/s]
#
#
#  34%|███▍      | 139380/404351 [00:23<00:43, 6088.96it/s]
#
#
#  35%|███▍      | 139990/404351 [00:23<00:43, 6059.46it/s]
#
#
#  35%|███▍      | 140597/404351 [00:23<00:44, 5969.96it/s]
#
#
#  35%|███▍      | 141195/404351 [00:23<00:44, 5938.92it/s]
#
#
#  35%|███▌      | 141797/404351 [00:23<00:44, 5960.92it/s]
#
#
#  35%|███▌      | 142394/404351 [00:24<00:44, 5841.64it/s]
#  35%|███▌      | 143012/404351 [00:24<00:44, 5937.64it/s]
#
#
#  36%|███▌      | 143621/404351 [00:24<00:43, 5982.19it/s]
#
#
#  36%|███▌      | 144236/404351 [00:24<00:43, 6030.31it/s]
#
#
#  36%|███▌      | 144840/404351 [00:24<00:43, 5993.38it/s]
#
#
#  36%|███▌      | 145440/404351 [00:24<00:43, 5970.73it/s]
#
#
#  36%|███▌      | 146038/404351 [00:24<00:44, 5789.20it/s]
#
#
#  36%|███▋      | 146630/404351 [00:24<00:44, 5824.44it/s]
#
#
#  36%|███▋      | 147246/404351 [00:24<00:43, 5920.20it/s]
#
#
#  37%|███▋      | 147840/404351 [00:24<00:43, 5885.93it/s]
#
#
#  37%|███▋      | 148450/404351 [00:25<00:43, 5948.05it/s]
#
#
#  37%|███▋      | 149046/404351 [00:25<00:43, 5936.56it/s]
#
#
#  37%|███▋      | 149641/404351 [00:25<00:42, 5936.30it/s]
#
#
#  37%|███▋      | 150235/404351 [00:25<00:43, 5782.99it/s]
#
#
#  37%|███▋      | 150815/404351 [00:25<00:44, 5755.19it/s]
#
#
#  37%|███▋      | 151432/404351 [00:25<00:43, 5873.59it/s]
#
#
#  38%|███▊      | 152058/404351 [00:25<00:42, 5983.55it/s]
#
#
#  38%|███▊      | 152658/404351 [00:25<00:42, 5950.17it/s]
#
#
#  38%|███▊      | 153270/404351 [00:25<00:41, 5996.93it/s]
#
#
#  38%|███▊      | 153871/404351 [00:25<00:42, 5899.03it/s]
#
#
#  38%|███▊      | 154462/404351 [00:26<00:42, 5889.96it/s]
#
#
#  38%|███▊      | 155058/404351 [00:26<00:42, 5909.83it/s]
#
#
#  38%|███▊      | 155650/404351 [00:26<00:42, 5882.60it/s]
#
#
#  39%|███▊      | 156239/404351 [00:26<00:42, 5882.91it/s]
#
#
#  39%|███▉      | 156853/404351 [00:26<00:41, 5957.73it/s]
#
#
#  39%|███▉      | 157476/404351 [00:26<00:40, 6035.98it/s]
#
#
#  39%|███▉      | 158081/404351 [00:26<00:41, 5915.92it/s]
#
#
#  39%|███▉      | 158674/404351 [00:26<00:42, 5722.54it/s]
#
#
#  39%|███▉      | 159249/404351 [00:26<00:42, 5722.67it/s]
#
#
#  40%|███▉      | 159852/404351 [00:26<00:42, 5810.10it/s]
#
#
#  52%|█████▏    | 208323/404351 [00:35<00:32, 6061.09it/s]
#
#
#  52%|█████▏    | 208930/404351 [00:35<00:33, 5920.65it/s]
#
#
#  52%|█████▏    | 209550/404351 [00:35<00:32, 5999.27it/s]
#
#
#  52%|█████▏    | 210151/404351 [00:35<00:32, 5896.83it/s]
#
#
#  52%|█████▏    | 210742/404351 [00:35<00:33, 5835.92it/s]
#
#
#  52%|█████▏    | 211327/404351 [00:36<00:33, 5744.52it/s]
#
#
#  52%|█████▏    | 211925/404351 [00:36<00:33, 5813.07it/s]
#
#
#  53%|█████▎    | 212521/404351 [00:36<00:32, 5856.38it/s]
#
#
#  53%|█████▎    | 213108/404351 [00:36<00:32, 5821.65it/s]
#
#
#  53%|█████▎    | 213741/404351 [00:36<00:31, 5963.80it/s]
#  53%|█████▎    | 214339/404351 [00:36<00:32, 5927.55it/s]
#
#
#  53%|█████▎    | 214949/404351 [00:36<00:31, 5977.88it/s]
#
#
#  53%|█████▎    | 215548/404351 [00:36<00:31, 5903.52it/s]
#
#
#  53%|█████▎    | 216164/404351 [00:36<00:31, 5977.44it/s]
#
#
#  54%|█████▎    | 216763/404351 [00:36<00:31, 5887.35it/s]
#
#
#  54%|█████▍    | 217353/404351 [00:37<00:32, 5672.13it/s]
#
#
#  54%|█████▍    | 217978/404351 [00:37<00:31, 5832.24it/s]
#
#
#  54%|█████▍    | 218564/404351 [00:37<00:31, 5828.95it/s]
#
#
#  54%|█████▍    | 219149/404351 [00:37<00:31, 5802.45it/s]
#
#
#  54%|█████▍    | 219731/404351 [00:37<00:31, 5779.91it/s]
#
#
#  54%|█████▍    | 220345/404351 [00:37<00:31, 5878.91it/s]
#
#
#  55%|█████▍    | 220942/404351 [00:37<00:31, 5902.28it/s]
#
#
#  55%|█████▍    | 221534/404351 [00:37<00:31, 5853.40it/s]
#
#
#  55%|█████▍    | 222131/404351 [00:37<00:30, 5885.77it/s]
#
#
#  55%|█████▌    | 222721/404351 [00:37<00:30, 5889.91it/s]
#
#
#  55%|█████▌    | 223311/404351 [00:38<00:31, 5708.13it/s]
#
#
#  55%|█████▌    | 223886/404351 [00:38<00:31, 5719.93it/s]
#
#
#  56%|█████▌    | 224476/404351 [00:38<00:31, 5772.43it/s]
#
#
#  56%|█████▌    | 225055/404351 [00:38<00:31, 5769.88it/s]
#
#
#  56%|█████▌    | 225633/404351 [00:38<00:31, 5685.37it/s]
#
#
#  56%|█████▌    | 226210/404351 [00:38<00:31, 5708.82it/s]
#
#
#  56%|█████▌    | 226806/404351 [00:38<00:30, 5781.54it/s]
#
#
#  56%|█████▌    | 227385/404351 [00:38<00:31, 5684.90it/s]
#
#
#  56%|█████▋    | 227979/404351 [00:38<00:30, 5757.74it/s]
#
#
#  57%|█████▋    | 228560/404351 [00:38<00:30, 5772.34it/s]
#
#
#  57%|█████▋    | 229170/404351 [00:39<00:29, 5865.40it/s]
#
#
#  57%|█████▋    | 229775/404351 [00:39<00:29, 5916.87it/s]
#
#
#  57%|█████▋    | 230390/404351 [00:39<00:29, 5983.22it/s]
#
#
#  57%|█████▋    | 230989/404351 [00:39<00:29, 5928.38it/s]
#
#
#  57%|█████▋    | 231595/404351 [00:39<00:28, 5965.43it/s]
#
#
#  57%|█████▋    | 232198/404351 [00:39<00:28, 5984.46it/s]
#
#
#  58%|█████▊    | 232819/404351 [00:39<00:28, 6047.27it/s]
#
#
#  58%|█████▊    | 233425/404351 [00:39<00:28, 5961.58it/s]
#
#
#  58%|█████▊    | 234022/404351 [00:39<00:29, 5840.47it/s]
#
#
#  58%|█████▊    | 234607/404351 [00:39<00:29, 5794.62it/s]
#
#
#  58%|█████▊    | 235205/404351 [00:40<00:28, 5848.09it/s]
#
#
#  58%|█████▊    | 235807/404351 [00:40<00:28, 5897.79it/s]
#
#
#  58%|█████▊    | 236421/404351 [00:40<00:28, 5966.51it/s]
#
#
#  59%|█████▊    | 237019/404351 [00:40<00:28, 5897.03it/s]
#
#
#  59%|█████▉    | 237647/404351 [00:40<00:27, 6005.57it/s]
#
#
#  59%|█████▉    | 238279/404351 [00:40<00:27, 6096.30it/s]
#
#
#  59%|█████▉    | 238890/404351 [00:40<00:27, 5957.72it/s]
#
#
#  59%|█████▉    | 239488/404351 [00:40<00:27, 5921.68it/s]
#
#
#  59%|█████▉    | 240084/404351 [00:40<00:27, 5931.50it/s]
#
#
#  60%|█████▉    | 240678/404351 [00:40<00:27, 5885.19it/s]
#
#
#  60%|█████▉    | 241268/404351 [00:41<00:27, 5837.09it/s]
#
#
#  60%|█████▉    | 241878/404351 [00:41<00:27, 5911.64it/s]
#
#
#  60%|█████▉    | 242470/404351 [00:41<00:28, 5683.96it/s]
#
#
#  60%|██████    | 243058/404351 [00:41<00:28, 5739.31it/s]
#
#
#  60%|██████    | 243657/404351 [00:41<00:27, 5810.88it/s]
#
#
#  60%|██████    | 244266/404351 [00:41<00:27, 5890.77it/s]
#
#
#  61%|██████    | 244857/404351 [00:41<00:27, 5871.95it/s]
#
#
#  61%|██████    | 245446/404351 [00:41<00:27, 5776.41it/s]
#
#
#  61%|██████    | 246025/404351 [00:41<00:27, 5740.06it/s]
#
#
#  61%|██████    | 246630/404351 [00:42<00:27, 5828.44it/s]
#
#
#  61%|██████    | 247215/404351 [00:42<00:26, 5833.74it/s]
#
#
#  61%|██████▏   | 247843/404351 [00:42<00:26, 5959.68it/s]
#
#
#  61%|██████▏   | 248441/404351 [00:42<00:26, 5933.21it/s]
#
#
#  62%|██████▏   | 249036/404351 [00:42<00:26, 5929.78it/s]
#
#
#  62%|██████▏   | 249641/404351 [00:42<00:25, 5964.71it/s]
#
#
#  62%|██████▏   | 250238/404351 [00:42<00:25, 5958.47it/s]
#
#
#  62%|██████▏   | 250835/404351 [00:42<00:26, 5784.35it/s]
#
#
#  62%|██████▏   | 251415/404351 [00:42<00:26, 5720.34it/s]
#
#
#  62%|██████▏   | 252000/404351 [00:42<00:26, 5758.53it/s]
#
#
#  62%|██████▏   | 252599/404351 [00:43<00:26, 5825.44it/s]
#
#
#  63%|██████▎   | 253183/404351 [00:43<00:25, 5825.16it/s]
#
#
#  63%|██████▎   | 253812/404351 [00:43<00:25, 5953.03it/s]
#
#
#  63%|██████▎   | 254409/404351 [00:43<00:25, 5907.47it/s]
#
#
#  63%|██████▎   | 255001/404351 [00:43<00:25, 5882.01it/s]
#
#
#  63%|██████▎   | 255614/404351 [00:43<00:24, 5952.42it/s]
#
#
#  63%|██████▎   | 256210/404351 [00:43<00:24, 5932.32it/s]
#
#
#  64%|██████▎   | 256804/404351 [00:43<00:24, 5918.92it/s]
#
#
#  64%|██████▎   | 257397/404351 [00:43<00:25, 5855.15it/s]
#
#
#  64%|██████▍   | 258020/404351 [00:43<00:24, 5962.72it/s]
#
#
#  64%|██████▍   | 258627/404351 [00:44<00:24, 5992.39it/s]
#
#
#  64%|██████▍   | 259227/404351 [00:44<00:25, 5688.87it/s]
#
#
#  64%|██████▍   | 259825/404351 [00:44<00:25, 5772.58it/s]
#
#
#  64%|██████▍   | 260435/404351 [00:44<00:24, 5864.20it/s]
#
#
#  65%|██████▍   | 261024/404351 [00:44<00:24, 5793.72it/s]
#
#
#  65%|██████▍   | 261606/404351 [00:44<00:25, 5704.84it/s]
#
#
#  65%|██████▍   | 262202/404351 [00:44<00:24, 5775.51it/s]
#
#
#  65%|██████▍   | 262786/404351 [00:44<00:24, 5793.81it/s]
#
#
#  65%|██████▌   | 263395/404351 [00:44<00:23, 5875.90it/s]
#
#
#  65%|██████▌   | 263984/404351 [00:44<00:23, 5855.35it/s]
#
#
#  65%|██████▌   | 264582/404351 [00:45<00:23, 5891.09it/s]
#
#
#  66%|██████▌   | 265188/404351 [00:45<00:23, 5940.01it/s]
#
#
#  66%|██████▌   | 265788/404351 [00:45<00:23, 5956.66it/s]
#
#
#  66%|██████▌   | 266385/404351 [00:45<00:23, 5898.17it/s]
#
#
#  66%|██████▌   | 266980/404351 [00:45<00:23, 5909.53it/s]
#
#
#  66%|██████▌   | 267572/404351 [00:45<00:23, 5736.81it/s]
#
#
#  66%|██████▋   | 268147/404351 [00:46<00:54, 2503.38it/s]
#
#
#  66%|██████▋   | 268719/404351 [00:46<00:45, 3010.45it/s]
#
#
#  67%|██████▋   | 269333/404351 [00:46<00:37, 3553.52it/s]
#
#
#  67%|██████▋   | 269895/404351 [00:46<00:33, 3992.72it/s]
#
#
#  67%|██████▋   | 270487/404351 [00:46<00:30, 4424.74it/s]
#
#
#  67%|██████▋   | 271094/404351 [00:46<00:27, 4815.98it/s]
#
#
#  67%|██████▋   | 271684/404351 [00:46<00:26, 5096.15it/s]
#
#
#  67%|██████▋   | 272277/404351 [00:46<00:24, 5317.80it/s]
#
#
#  67%|██████▋   | 272856/404351 [00:46<00:24, 5373.09it/s]
#
#
#  68%|██████▊   | 273436/404351 [00:47<00:23, 5492.84it/s]
#
#
#  68%|██████▊   | 274010/404351 [00:47<00:23, 5560.70it/s]
#
#
#  68%|██████▊   | 274603/404351 [00:47<00:22, 5664.53it/s]
#
#
#  68%|██████▊   | 275225/404351 [00:47<00:22, 5817.81it/s]
#
#
#  68%|██████▊   | 275817/404351 [00:47<00:22, 5781.75it/s]
#
#
#  68%|██████▊   | 276402/404351 [00:47<00:22, 5630.37it/s]
#
#
#  80%|████████  | 323488/404351 [00:55<00:13, 5814.59it/s]
#
#
#  80%|████████  | 324094/404351 [00:55<00:13, 5883.40it/s]
#
#
#  80%|████████  | 324684/404351 [00:55<00:13, 5848.81it/s]
#
#
#  80%|████████  | 325270/404351 [00:55<00:13, 5822.25it/s]
#
#
#  81%|████████  | 325853/404351 [00:55<00:13, 5802.14it/s]
#
#
#  81%|████████  | 326434/404351 [00:56<00:13, 5651.54it/s]
#
#
#  81%|████████  | 327024/404351 [00:56<00:13, 5721.49it/s]
#
#
#  81%|████████  | 327622/404351 [00:56<00:13, 5795.01it/s]
#
#
#  81%|████████  | 328207/404351 [00:56<00:13, 5810.43it/s]
#
#
#  81%|████████▏ | 328818/404351 [00:56<00:12, 5896.54it/s]
#
#
#  81%|████████▏ | 329430/404351 [00:56<00:12, 5958.99it/s]
#
#
#  82%|████████▏ | 330027/404351 [00:56<00:12, 5856.41it/s]
#
#
#  82%|████████▏ | 330614/404351 [00:56<00:12, 5794.80it/s]
#
#
#  82%|████████▏ | 331200/404351 [00:56<00:12, 5811.96it/s]
#
#
#  82%|████████▏ | 331794/404351 [00:56<00:12, 5848.03it/s]
#
#
#  82%|████████▏ | 332413/404351 [00:57<00:12, 5944.34it/s]
#
#
#  82%|████████▏ | 333009/404351 [00:57<00:12, 5910.48it/s]
#
#
#  83%|████████▎ | 333601/404351 [00:57<00:12, 5847.83it/s]
#
#
#  83%|████████▎ | 334200/404351 [00:57<00:11, 5888.53it/s]
#
#
#  83%|████████▎ | 334790/404351 [00:57<00:12, 5761.12it/s]
#
#
#  83%|████████▎ | 335371/404351 [00:57<00:11, 5775.04it/s]
#
#
#  83%|████████▎ | 335950/404351 [00:57<00:11, 5774.90it/s]
#
#
#  83%|████████▎ | 336552/404351 [00:57<00:11, 5844.32it/s]
#
#
#  83%|████████▎ | 337181/404351 [00:57<00:11, 5969.11it/s]
#
#
#  84%|████████▎ | 337786/404351 [00:57<00:11, 5991.20it/s]
#
#
#  84%|████████▎ | 338386/404351 [00:58<00:11, 5988.80it/s]
#
#
#  84%|████████▍ | 338995/404351 [00:58<00:10, 6016.91it/s]
#
#
#  84%|████████▍ | 339598/404351 [00:58<00:10, 5984.20it/s]
#
#
#  84%|████████▍ | 340197/404351 [00:58<00:10, 5914.18it/s]
#
#
#  84%|████████▍ | 340794/404351 [00:58<00:10, 5930.09it/s]
#
#
#  84%|████████▍ | 341396/404351 [00:58<00:10, 5956.20it/s]
#
#
#  85%|████████▍ | 341992/404351 [00:58<00:10, 5879.84it/s]
#
#
#  85%|████████▍ | 342581/404351 [00:58<00:10, 5818.71it/s]
#
#
#  85%|████████▍ | 343164/404351 [00:58<00:10, 5704.50it/s]
#
#
#  85%|████████▌ | 343748/404351 [00:58<00:10, 5741.94it/s]
#
#
#  85%|████████▌ | 344356/404351 [00:59<00:10, 5838.67it/s]
#
#
#  85%|████████▌ | 344947/404351 [00:59<00:10, 5859.35it/s]
#
#
#  85%|████████▌ | 345534/404351 [00:59<00:10, 5821.27it/s]
#
#
#  86%|████████▌ | 346144/404351 [00:59<00:09, 5900.84it/s]
#
#
#  86%|████████▌ | 346735/404351 [00:59<00:09, 5868.03it/s]
#
#
#  86%|████████▌ | 347323/404351 [00:59<00:09, 5841.12it/s]
#
#
#  86%|████████▌ | 347925/404351 [00:59<00:09, 5892.59it/s]
#
#
#  86%|████████▌ | 348515/404351 [00:59<00:09, 5887.75it/s]
#
#
#  86%|████████▋ | 349110/404351 [00:59<00:09, 5903.79it/s]
#
#
#  86%|████████▋ | 349706/404351 [00:59<00:09, 5917.00it/s]
#
#
#  87%|████████▋ | 350298/404351 [01:00<00:09, 5878.58it/s]
#
#
#  87%|████████▋ | 350887/404351 [01:00<00:09, 5875.55it/s]
#
#
#  87%|████████▋ | 351475/404351 [01:00<00:09, 5804.88it/s]
#
#
#  87%|████████▋ | 352075/404351 [01:00<00:08, 5857.48it/s]
#
#
#  87%|████████▋ | 352662/404351 [01:00<00:08, 5853.39it/s]
#
#
#  87%|████████▋ | 353248/404351 [01:00<00:08, 5823.84it/s]
#
#
#  88%|████████▊ | 353831/404351 [01:00<00:08, 5797.50it/s]
#
#
#  88%|████████▊ | 354443/404351 [01:00<00:08, 5889.22it/s]
#
#
#  88%|████████▊ | 355033/404351 [01:00<00:08, 5814.47it/s]
#  88%|████████▊ | 355627/404351 [01:00<00:08, 5849.55it/s]
#
#
#  88%|████████▊ | 356213/404351 [01:01<00:08, 5714.44it/s]
#
#
#  88%|████████▊ | 356814/404351 [01:01<00:08, 5796.88it/s]
#
#
#  88%|████████▊ | 357402/404351 [01:01<00:08, 5820.11it/s]
#
#
#  89%|████████▊ | 358009/404351 [01:01<00:07, 5891.48it/s]
#
#
#  89%|████████▊ | 358599/404351 [01:01<00:07, 5804.59it/s]
#
#
#  89%|████████▉ | 359181/404351 [01:01<00:07, 5757.27it/s]
#
#
#  89%|████████▉ | 359758/404351 [01:01<00:07, 5590.71it/s]
#
#
#  89%|████████▉ | 360377/404351 [01:01<00:07, 5756.71it/s]
#
#
#  89%|████████▉ | 360987/404351 [01:01<00:07, 5854.91it/s]
#
#
#  89%|████████▉ | 361596/404351 [01:02<00:07, 5922.63it/s]
#
#
#  90%|████████▉ | 362215/404351 [01:02<00:07, 5999.51it/s]
#
#
#  90%|████████▉ | 362817/404351 [01:02<00:06, 5936.39it/s]
#
#
#  90%|████████▉ | 363412/404351 [01:02<00:07, 5814.29it/s]
#
#
#  90%|█████████ | 364025/404351 [01:02<00:06, 5905.40it/s]
#
#
#  90%|█████████ | 364633/404351 [01:02<00:06, 5956.56it/s]
#
#
#  90%|█████████ | 365238/404351 [01:02<00:06, 5980.33it/s]
#
#
#  90%|█████████ | 365843/404351 [01:02<00:06, 5998.76it/s]
#
#
#  91%|█████████ | 366446/404351 [01:02<00:06, 6006.70it/s]
#
#
#  91%|█████████ | 367048/404351 [01:02<00:06, 6000.62it/s]
#
#
#  91%|█████████ | 367649/404351 [01:03<00:06, 5872.08it/s]
#
#
#  91%|█████████ | 368246/404351 [01:03<00:06, 5898.88it/s]
#
#
#  91%|█████████ | 368851/404351 [01:03<00:05, 5940.88it/s]
#
#
#  91%|█████████▏| 369450/404351 [01:03<00:05, 5953.40it/s]
#
#
#  92%|█████████▏| 370052/404351 [01:03<00:05, 5971.74it/s]
#
#
#  92%|█████████▏| 370670/404351 [01:03<00:05, 6030.43it/s]
#
#
#  92%|█████████▏| 371274/404351 [01:03<00:05, 5963.21it/s]
#
#
#  92%|█████████▏| 371872/404351 [01:03<00:05, 5967.84it/s]
#
#
#  92%|█████████▏| 372470/404351 [01:03<00:05, 5908.65it/s]
#
#
#  92%|█████████▏| 373062/404351 [01:03<00:05, 5831.65it/s]
#
#
#  92%|█████████▏| 373647/404351 [01:04<00:05, 5836.21it/s]
#
#
#  93%|█████████▎| 374231/404351 [01:04<00:05, 5806.19it/s]
#
#
#  93%|█████████▎| 374836/404351 [01:04<00:05, 5876.93it/s]
#
#
#  93%|█████████▎| 375439/404351 [01:04<00:04, 5920.86it/s]
#
#
#  93%|█████████▎| 376032/404351 [01:04<00:04, 5707.31it/s]
#
#
#  93%|█████████▎| 376635/404351 [01:04<00:04, 5799.54it/s]
#
#
#  93%|█████████▎| 377224/404351 [01:04<00:04, 5819.88it/s]
#
#
#  93%|█████████▎| 377841/404351 [01:04<00:04, 5917.87it/s]
#
#
#  94%|█████████▎| 378435/404351 [01:04<00:04, 5918.60it/s]
#
#
#  94%|█████████▎| 379028/404351 [01:04<00:04, 5782.39it/s]
#
#
#  94%|█████████▍| 379608/404351 [01:05<00:04, 5762.15it/s]
#
#
#  94%|█████████▍| 380192/404351 [01:05<00:04, 5784.04it/s]
#
#
#  94%|█████████▍| 380772/404351 [01:05<00:04, 5567.59it/s]
#
#
#  94%|█████████▍| 381344/404351 [01:05<00:04, 5611.49it/s]
#
#
#  94%|█████████▍| 381961/404351 [01:05<00:03, 5767.27it/s]
#
#
#  95%|█████████▍| 382559/404351 [01:05<00:03, 5827.76it/s]
#
#
#  95%|█████████▍| 383162/404351 [01:05<00:03, 5883.00it/s]
#
#
#  95%|█████████▍| 383752/404351 [01:05<00:03, 5799.88it/s]
#
#
#  95%|█████████▌| 384334/404351 [01:05<00:03, 5729.32it/s]
#
#
#  95%|█████████▌| 384908/404351 [01:06<00:09, 2110.93it/s]
#
#
#  95%|█████████▌| 385374/404351 [01:06<00:07, 2525.27it/s]
#
#
#  95%|█████████▌| 385973/404351 [01:06<00:06, 3054.64it/s]
#
#
#  96%|█████████▌| 386547/404351 [01:06<00:05, 3552.69it/s]
#
#
#  96%|█████████▌| 387123/404351 [01:06<00:04, 4014.04it/s]
#
#
#  96%|█████████▌| 387740/404351 [01:07<00:03, 4483.90it/s]
#
#
#  96%|█████████▌| 388344/404351 [01:07<00:03, 4856.44it/s]
#
#
#  96%|█████████▌| 388915/404351 [01:07<00:03, 5080.83it/s]
#
#
#  96%|█████████▋| 389486/404351 [01:07<00:02, 5225.86it/s]
#
#
#  96%|█████████▋| 390084/404351 [01:07<00:02, 5430.46it/s]
#
#
#  97%|█████████▋| 390668/404351 [01:07<00:02, 5545.29it/s]
#
#
#  97%|█████████▋| 391260/404351 [01:07<00:02, 5648.15it/s]
#
#
#  97%|█████████▋| 391843/404351 [01:07<00:02, 5643.37it/s]
#
#
#  97%|█████████▋| 392422/404351 [01:07<00:02, 5683.85it/s]
#
#
#  97%|█████████▋| 393018/404351 [01:07<00:01, 5762.11it/s]
#
#
#  97%|█████████▋| 393601/404351 [01:08<00:01, 5576.40it/s]
#
#
#  97%|█████████▋| 394193/404351 [01:08<00:01, 5670.41it/s]
#
#
#  98%|█████████▊| 394765/404351 [01:08<00:01, 5658.18it/s]
#
#
#  98%|█████████▊| 395336/404351 [01:08<00:01, 5671.25it/s]
#
#
#  98%|█████████▊| 395906/404351 [01:08<00:01, 5576.28it/s]
#
#
#  98%|█████████▊| 396519/404351 [01:08<00:01, 5730.87it/s]
#
#
#  98%|█████████▊| 397095/404351 [01:08<00:01, 5708.19it/s]
#
#
#  98%|█████████▊| 397685/404351 [01:08<00:01, 5763.78it/s]
#
#
#  98%|█████████▊| 398264/404351 [01:08<00:01, 5770.80it/s]
#
#
#  99%|█████████▊| 398868/404351 [01:08<00:00, 5848.22it/s]
#
#
#  99%|█████████▉| 399461/404351 [01:09<00:00, 5869.64it/s]
#
#
#  99%|█████████▉| 400070/404351 [01:09<00:00, 5932.01it/s]
#
#
#  99%|█████████▉| 400664/404351 [01:09<00:00, 5860.37it/s]
#
#
#  99%|█████████▉| 401251/404351 [01:09<00:00, 5836.34it/s]
#
#
#  99%|█████████▉| 401836/404351 [01:09<00:00, 5678.83it/s]
#
#
# 100%|█████████▉| 402443/404351 [01:09<00:00, 5789.79it/s]
#
#
# 100%|█████████▉| 403028/404351 [01:09<00:00, 5801.57it/s]
#
#
# 100%|█████████▉| 403610/404351 [01:09<00:00, 5755.95it/s]
#
#
# 100%|█████████▉| 404187/404351 [01:09<00:00, 5642.18it/s]
#
#
# 100%|██████████| 404351/404351 [01:09<00:00, 5781.46it/s]
#
#
#   0%|          | 0/404351 [00:00<?, ?it/s]
#
#
#   0%|          | 551/404351 [00:00<01:13, 5506.30it/s]
#
#
#   0%|          | 1134/404351 [00:00<01:12, 5597.93it/s]
#
#
#   0%|          | 1713/404351 [00:00<01:11, 5652.05it/s]
#
#
#   1%|          | 2281/404351 [00:00<01:11, 5659.25it/s]
#
#
#   1%|          | 2836/404351 [00:00<01:11, 5625.26it/s]
#
#
#   1%|          | 3474/404351 [00:00<01:08, 5825.79it/s]
#
#
#   1%|          | 4092/404351 [00:00<01:07, 5925.94it/s]
#
#
#   1%|          | 4664/404351 [00:00<01:08, 5862.44it/s]
#
#
#   1%|▏         | 5272/404351 [00:00<01:07, 5925.71it/s]
#
#
#   1%|▏         | 5849/404351 [00:01<01:07, 5877.19it/s]
#
#
#   2%|▏         | 6435/404351 [00:01<01:07, 5869.53it/s]
#
#
#   2%|▏         | 7043/404351 [00:01<01:06, 5930.62it/s]
#
#
#   2%|▏         | 7649/404351 [00:01<01:06, 5967.97it/s]
#
#
#   2%|▏         | 8254/404351 [00:01<01:06, 5992.22it/s]
#
#
#   2%|▏         | 8859/404351 [00:01<01:05, 6007.81it/s]
#
#
#   2%|▏         | 9458/404351 [00:01<01:06, 5969.24it/s]
#
#
#   2%|▏         | 10055/404351 [00:01<01:06, 5969.04it/s]
#
#
#   3%|▎         | 10651/404351 [00:01<01:06, 5892.86it/s]
#
#
#   3%|▎         | 11245/404351 [00:01<01:06, 5900.57it/s]
#
#
#   3%|▎         | 11838/404351 [00:02<01:06, 5907.37it/s]
#
#
#   3%|▎         | 12451/404351 [00:02<01:05, 5972.31it/s]
#
#
#   3%|▎         | 13068/404351 [00:02<01:04, 6028.08it/s]
#
#
#   3%|▎         | 13671/404351 [00:02<01:06, 5917.91it/s]
#
#
#   4%|▎         | 14264/404351 [00:02<01:12, 5378.13it/s]
#
#
#   4%|▎         | 14812/404351 [00:02<01:12, 5382.74it/s]
#
#
#   4%|▍         | 15367/404351 [00:02<01:11, 5429.91it/s]
#
#
#   4%|▍         | 15988/404351 [00:02<01:08, 5642.43it/s]
#
#
#   4%|▍         | 16594/404351 [00:02<01:07, 5755.44it/s]
#
#
#   4%|▍         | 17175/404351 [00:02<01:07, 5743.15it/s]
#
#
#   4%|▍         | 17798/404351 [00:03<01:05, 5879.06it/s]
#
#
#   5%|▍         | 18389/404351 [00:03<01:07, 5756.23it/s]
#
#
#   5%|▍         | 19009/404351 [00:03<01:05, 5882.28it/s]
#
#
#   5%|▍         | 19613/404351 [00:03<01:04, 5924.55it/s]
#
#
#   5%|▍         | 20209/404351 [00:03<01:04, 5932.56it/s]
#   5%|▌         | 20804/404351 [00:03<01:05, 5900.40it/s]
#
#
#   5%|▌         | 21399/404351 [00:03<01:04, 5913.98it/s]
#
#
#   5%|▌         | 21992/404351 [00:03<01:04, 5904.17it/s]
#
#
#   6%|▌         | 22583/404351 [00:03<01:06, 5727.30it/s]
#
#
#   6%|▌         | 23158/404351 [00:03<01:06, 5722.16it/s]
#
#
#   6%|▌         | 23763/404351 [00:04<01:05, 5814.99it/s]
#
#
#   6%|▌         | 24346/404351 [00:04<01:05, 5803.03it/s]
#
#
#   6%|▌         | 24928/404351 [00:04<01:06, 5721.06it/s]
#
#
#   6%|▋         | 25501/404351 [00:04<01:06, 5716.97it/s]
#
#
#   6%|▋         | 26105/404351 [00:04<01:05, 5809.57it/s]
#
#
#   7%|▋         | 26729/404351 [00:04<01:03, 5931.39it/s]
#
#
#   7%|▋         | 27331/404351 [00:04<01:03, 5956.63it/s]
#
#
#   7%|▋         | 27935/404351 [00:04<01:02, 5981.22it/s]
#
#
#   7%|▋         | 28534/404351 [00:04<01:03, 5900.23it/s]
#
#
#   7%|▋         | 29148/404351 [00:04<01:02, 5968.80it/s]
#
#
#   7%|▋         | 29746/404351 [00:05<01:03, 5887.40it/s]
#
#
#   8%|▊         | 30336/404351 [00:05<01:04, 5798.51it/s]
#
#
#   8%|▊         | 30917/404351 [00:05<01:08, 5422.59it/s]
#
#
#   8%|▊         | 31473/404351 [00:05<01:08, 5460.07it/s]
#
#
#   8%|▊         | 32064/404351 [00:05<01:06, 5585.96it/s]
#
#
#   8%|▊         | 32627/404351 [00:05<01:06, 5557.70it/s]
#
#
#   8%|▊         | 33223/404351 [00:05<01:05, 5671.11it/s]
#
#
#   8%|▊         | 33793/404351 [00:05<01:05, 5656.31it/s]
#
#
#   9%|▊         | 34400/404351 [00:05<01:04, 5773.49it/s]
#
#
#   9%|▊         | 35023/404351 [00:06<01:02, 5901.78it/s]
#
#
#   9%|▉         | 35617/404351 [00:06<01:02, 5910.62it/s]
#
#
#   9%|▉         | 36210/404351 [00:06<01:03, 5815.63it/s]
#
#
#   9%|▉         | 36825/404351 [00:06<01:02, 5912.03it/s]
#
#
#   9%|▉         | 37449/404351 [00:06<01:01, 6005.16it/s]
#
#
#   9%|▉         | 38070/404351 [00:06<01:00, 6062.71it/s]
#
#
#  10%|▉         | 38678/404351 [00:06<01:00, 6028.15it/s]
#
#
#  10%|▉         | 39282/404351 [00:06<01:02, 5870.94it/s]
#
#
#  10%|▉         | 39882/404351 [00:06<01:01, 5906.33it/s]
#
#
#  10%|█         | 40474/404351 [00:06<01:02, 5835.67it/s]
#
#
#  10%|█         | 41063/404351 [00:07<01:02, 5850.99it/s]
#
#
#  10%|█         | 41649/404351 [00:07<01:02, 5798.24it/s]
#
#
#  10%|█         | 42245/404351 [00:07<01:01, 5845.50it/s]
#
#
#  11%|█         | 42831/404351 [00:07<01:02, 5812.99it/s]
#
#
#  11%|█         | 43422/404351 [00:07<01:01, 5840.59it/s]
#
#
#  11%|█         | 44007/404351 [00:07<01:03, 5692.69it/s]
#
#
#  11%|█         | 44578/404351 [00:07<01:03, 5635.55it/s]
#
#
#  11%|█         | 45169/404351 [00:07<01:02, 5713.27it/s]
#
#
#  11%|█▏        | 45760/404351 [00:07<01:02, 5755.68it/s]
#
#
#  11%|█▏        | 46384/404351 [00:07<01:00, 5891.27it/s]
#
#
#  12%|█▏        | 46977/404351 [00:08<01:00, 5899.80it/s]
#
#
#  12%|█▏        | 47568/404351 [00:08<01:02, 5709.29it/s]
#
#
#  12%|█▏        | 48142/404351 [00:08<01:02, 5717.50it/s]
#
#
#  12%|█▏        | 48716/404351 [00:08<01:02, 5666.12it/s]
#
#
#  12%|█▏        | 49321/404351 [00:08<01:01, 5772.56it/s]
#
#
#  12%|█▏        | 49908/404351 [00:08<01:01, 5801.32it/s]
#
#
#  12%|█▏        | 50516/404351 [00:08<01:00, 5882.18it/s]
#
#
#  13%|█▎        | 51106/404351 [00:08<01:00, 5844.54it/s]
#
#
#  13%|█▎        | 51692/404351 [00:08<01:00, 5792.16it/s]
#
#
#  13%|█▎        | 52272/404351 [00:08<01:01, 5740.18it/s]
#
#
#  13%|█▎        | 52887/404351 [00:09<01:00, 5856.69it/s]
#
#
#  13%|█▎        | 53474/404351 [00:09<01:01, 5751.78it/s]
#
#
#  13%|█▎        | 54064/404351 [00:09<01:00, 5789.45it/s]
#
#
#  14%|█▎        | 54644/404351 [00:09<01:01, 5723.25it/s]
#
#
#  14%|█▎        | 55251/404351 [00:09<00:59, 5822.86it/s]
#
#
#  14%|█▍        | 55835/404351 [00:09<01:00, 5727.51it/s]
#
#
#  14%|█▍        | 56409/404351 [00:09<01:01, 5692.58it/s]
#
#
#  14%|█▍        | 57017/404351 [00:09<00:59, 5801.01it/s]
#
#
#  14%|█▍        | 57599/404351 [00:09<01:00, 5763.81it/s]
#
#
#  14%|█▍        | 58182/404351 [00:10<00:59, 5782.01it/s]
#
#
#  15%|█▍        | 58761/404351 [00:10<01:00, 5741.81it/s]
#
#
#  15%|█▍        | 59336/404351 [00:10<01:00, 5730.97it/s]
#
#
#  15%|█▍        | 59910/404351 [00:10<01:00, 5724.19it/s]
#
#
#  15%|█▍        | 60514/404351 [00:10<00:59, 5812.34it/s]
#
#
#  15%|█▌        | 61129/404351 [00:10<00:58, 5909.25it/s]
#
#
#  15%|█▌        | 61741/404351 [00:10<00:57, 5964.03it/s]
#
#
#  15%|█▌        | 62339/404351 [00:10<00:57, 5901.69it/s]
#
#
#  16%|█▌        | 62941/404351 [00:10<00:57, 5933.39it/s]
#
#
#  16%|█▌        | 63535/404351 [00:10<00:57, 5892.19it/s]
#
#
#  16%|█▌        | 64125/404351 [00:11<01:00, 5666.64it/s]
#
#
#  16%|█▌        | 64706/404351 [00:11<00:59, 5707.25it/s]
#
#
#  16%|█▌        | 65279/404351 [00:11<01:00, 5584.59it/s]
#
#
#  16%|█▋        | 65869/404351 [00:11<00:59, 5675.25it/s]
#
#
#  16%|█▋        | 66457/404351 [00:11<00:58, 5733.42it/s]
#
#
#  17%|█▋        | 67054/404351 [00:11<00:58, 5801.02it/s]
#
#
#  17%|█▋        | 67676/404351 [00:11<00:56, 5919.55it/s]
#
#
#  17%|█▋        | 68270/404351 [00:11<00:56, 5916.53it/s]
#
#
#  17%|█▋        | 68863/404351 [00:11<00:57, 5885.27it/s]
#
#
#  17%|█▋        | 69453/404351 [00:11<00:57, 5831.46it/s]
#
#
#  17%|█▋        | 70037/404351 [00:12<00:57, 5818.50it/s]
#
#
#  17%|█▋        | 70623/404351 [00:12<00:57, 5825.93it/s]
#
#
#  18%|█▊        | 71207/404351 [00:12<00:57, 5829.15it/s]
#
#
#  18%|█▊        | 71796/404351 [00:12<00:56, 5844.94it/s]
#
#
#  18%|█▊        | 72381/404351 [00:12<00:57, 5736.30it/s]
#
#
#  18%|█▊        | 72992/404351 [00:12<00:56, 5841.98it/s]
#
#
#  18%|█▊        | 73606/404351 [00:12<00:55, 5926.17it/s]
#
#
#  18%|█▊        | 74218/404351 [00:12<00:55, 5981.69it/s]
#
#
#  19%|█▊        | 74817/404351 [00:12<00:55, 5975.33it/s]
#
#
#  19%|█▊        | 75416/404351 [00:12<00:56, 5833.45it/s]
#
#
#  19%|█▉        | 76001/404351 [00:13<00:57, 5704.37it/s]
#
#
#  19%|█▉        | 76618/404351 [00:13<00:56, 5834.80it/s]
#
#
#  19%|█▉        | 77223/404351 [00:13<00:55, 5896.65it/s]
#
#
#  19%|█▉        | 77815/404351 [00:13<00:56, 5765.63it/s]
#
#
#  19%|█▉        | 78429/404351 [00:13<00:55, 5873.05it/s]
#
#
#  20%|█▉        | 79018/404351 [00:13<00:55, 5810.41it/s]
#
#
#  20%|█▉        | 79601/404351 [00:13<00:56, 5762.12it/s]
#
#
#  20%|█▉        | 80211/404351 [00:13<00:55, 5856.43it/s]
#
#
/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-4359f5935f1a> in <module>
#       4 question1 = convert_lines(file["question1"], max_sequence_length, tokenizer)
#       5 #file['question2'] = file['question2'].astype(str)
# ----> 6 question2 = convert_lines(file["question2"], max_sequence_length, tokenizer)
#       7 label = np.array(file['is_duplicate'])
#
# <ipython-input-64-1f9385b67d78> in convert_lines(sentence, max_seq_length, tokenizer)
#       3     all_tokens = []
#       4     for text in tqdm(sentence):
# ----> 5         tokens = tokenizer.tokenize(text)
#       6         if len(tokens)>max_seq_length:
#       7             tokens = tokens[:max_seq_length]
#
# ~/anaconda3/envs/mlp/lib/python3.6/site-packages/pytorch_pretrained_bert/tokenization.py in tokenize(self, text)
#      91     def tokenize(self, text):
#      92         split_tokens = []
# ---> 93         for token in self.basic_tokenizer.tokenize(text):
#      94             for sub_token in self.wordpiece_tokenizer.tokenize(token):
#      95                 split_tokens.append(sub_token)
#
# ~/anaconda3/envs/mlp/lib/python3.6/site-packages/pytorch_pretrained_bert/tokenization.py in tokenize(self, text)
#     171     def tokenize(self, text):
#     172         """Tokenizes a piece of text."""
# --> 173         text = self._clean_text(text)
#     174         # This was added on November 1st, 2018 for the multilingual and Chinese
#     175         # models. This is also applied to the English models now, but it doesn't
#
# ~/anaconda3/envs/mlp/lib/python3.6/site-packages/pytorch_pretrained_bert/tokenization.py in _clean_text(self, text)
#     261         """Performs invalid character removal and whitespace cleanup on text."""
#     262         output = []
# --> 263         for char in text:
#     264             cp = ord(char)
#     265             if cp == 0 or cp == 0xfffd or _is_control(char):
#
# TypeError: 'float' object is not iterable

# %%
import torch.utils.data.dataset as Dataset
import torch.utils.data.dataloader as DataLoader
#创建子类
class modelDataset(Dataset.Dataset):
    #初始化，定义数据内容和标签
    def __init__(self, data1, data2, label):
        self.data1 = data1
        self.data2 = data2
        self.label = label
    #返回数据集大小
    def __len__(self):
        return len(self.label)
    #得到数据内容和标签
    def __getitem__(self, index):
        data1 = torch.LongTensor(self.data1[index])
        data2 = torch.LongTensor(self.data2[index])
        label = torch.Tensor([self.label[index]])
        if torch.cuda.is_available():
            data1 = data1.cuda()
            data2 = data2.cuda()
            label = label.cuda()
        return [data1, data2], label

# %%
dataset = modelDataset(question1, question2, label)

# %%
class matchingModel(nn.Module):
    def __init__(self, pre_trained_model):
        super(matchingModel, self).__init__()
        
        self.model_query = BertModel.from_pretrained(pre_trained_model)
        self.model_bidword = BertModel.from_pretrained(pre_trained_model)
        self.dropout = nn.Dropout(p = 0.2)
        self.fc1 = nn.Linear(768*4, 256)
        self.fc2 = nn.Linear(256, 1) 
        
    def infer_metrics(self, x1, x2):
        return torch.cat((x1, x2, torch.abs(x1 - x2), x1 * x2), 1)
    
    def forward(self, input_data):
        
        query_vec = self.model_query(input_data[0])
        bidword_vec = self.model_bidword(input_data[1])
#         similarity_scores = self.infer_metrics(query_vec[1], bidword_vec[1])
#         similarity_scores = self.dropout(torch.tanh(self.fc1(similarity_scores)))
#         similarity_scores = self.fc2(similarity_scores)
        cos = nn.CosineSimilarity(dim=1, eps=1e-6)
        output = cos(query_vec[1], bidword_vec[1])
        
        return output

# %%
def accuracy(preds, y):
    preds = torch.sigmoid(preds, dim=1)
    correct = 0 
    pred = preds.max(1, keepdim=True)[1]
    correct += pred.eq(y.view_as(pred)).sum().item()
    acc = correct/len(y)

    return acc

# %%
lr=2e-5
batch_size = 2
#用于参数更新的加速，设为2，参数更新的次数为1的1/2
accumulation_steps=2
save_steps = 1000
checkpoint = None
EPOCHS = 1
num_train_optimization_steps = int(EPOCHS*len(label) / batch_size / accumulation_steps)
optimizer = BertAdam(model.parameters(),
                     lr=lr,  
                     warmup=0.05,   
                     t_total=num_train_optimization_steps)

model = matchingModel('bert-base-uncased')
model.train()
criterion = nn.BCELoss()
for epoch in tqdm(range(EPOCHS)):
#     file_name = 'loss_log_' + 'epoch' + str(epoch) + '.txt'
#     file = open(file_name, 'w', encoding='utf-8')
    train_loader = DataLoader.DataLoader(dataset, batch_size= batch_size, shuffle = True) 
    avg_loss = 0
    avg_accuracy = 0
    optimizer.zero_grad()   
    for x_batch, y_batch in tqdm(train_loader):
        y_pred = model(x_batch)
        loss = criterion(y_pred, y_batch) 
        loss.backward()  
        optimizer.step() 
        optimizer.zero_grad()
        avg_loss += loss.item() / len(train_loader)
        avg_accuracy += torch.mean(y_pred>0.5 == y_batch>0.5).to(torch.float).item()/len(train_loader)
#        i += 1
#         file.write('batch' + str(i) + '\t' + 'avg_loss' + '=' + str(avg_loss) + '\t' + 'avg_accuracy' + '=' + str(avg_accuracy) + '\n')
#     file.close()
#     file_path = output_model_file + str(epoch) +'.bin'
#     torch.save(model.state_dict(), file_path)
    print(f'loss:{avg_loss} accuracy:{avg_accuracy}')
# Out:
# INFO:pytorch_pretrained_bert.modeling:loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at /Users/LYB/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# INFO:pytorch_pretrained_bert.modeling:extracting archive file /Users/LYB/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /var/folders/r0/q62_cr2d4yb7h48zdx8tdrs00000gp/T/tmp48pjvq69
# INFO:pytorch_pretrained_bert.modeling:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# INFO:pytorch_pretrained_bert.modeling:loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at /Users/LYB/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# INFO:pytorch_pretrained_bert.modeling:extracting archive file /Users/LYB/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /var/folders/r0/q62_cr2d4yb7h48zdx8tdrs00000gp/T/tmp_uf7hccs
# INFO:pytorch_pretrained_bert.modeling:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/202176 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-197-8fe4e058c263> in <module>
#      29         optimizer.zero_grad()
#      30         avg_loss += loss.item() / len(train_loader)
# ---> 31         avg_accuracy += torch.mean(y_pred>0.5 == y_batch>0.5).to(torch.float).item()/len(train_loader)
#      32 #        i += 1
#      33 #         file.write('batch' + str(i) + '\t' + 'avg_loss' + '=' + str(avg_loss) + '\t' + 'avg_accuracy' + '=' + str(avg_accuracy) + '\n')
#
# RuntimeError: bool value of Tensor with more than one value is ambiguous
